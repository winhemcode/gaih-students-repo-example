# %% [markdown]
# Global AI Hub Final Projesi Kerem Basmacı Mail: kerembasmaci.20@gmail.com

# %% [markdown]
# ![finalproject.png](data:image/png;base64,...)

# %%
point=0

# %%
print("Phyton ilk kim tarafından geliştirilmiştir. Lütfen Tam Adını Yazınız")
answer = str(input('Cevabınız: '))
if answer.lower() == 'guido van rossum':
  print("Corret! ")
  point = point + 10
else:
  print("WRONG!")
# Out:
# Phyton ilk kim tarafından geliştirilmiştir. Lütfen Tam Adını Yazınız
# Cevabınız: Guido Van Rossum
# Corret!

# %%
print("Phyton ilk çıkışı hangi yılda olmuştur.")
answer = str(input('Cevabınız: '))
if answer.lower() == '1990':
  print("Corret! ")
  point = point + 10
else:
  print("WRONG!")
# Out:
# Phyton ilk çıkışı hangi yılda olmuştur.
# Cevabınız: 1990
# Corret!

# %%
print("Şu an phytonın en son sürümü kaçıncıdır")
answer = str(input('Cevabınız: '))
if answer.lower() == '3':
  print("Corret! ")
  point = point + 10
else:
  print("WRONG!")
# Out:
# Şu an phytonın en son sürümü kaçıncıdır
# Cevabınız: 3
# Corret!

# %%
print("Şu an phytonın en son sürümü kaçıncıdır")
answer = str(input('Cevabınız: '))
if answer.lower() == '3':
  print("Corret! ")
  point = point + 10
else:
  print("WRONG!")

# %%
print("Ondalık gösterim için kullanılan veri tipi nedir?")
answer = str(input('Cevabınız: '))
if answer.lower() == 'float':
  print("Corret! ")
  point = point + 10
else:
  print("WRONG!")
# Out:
# Ondalık gösterim için kullanılan veri tipi nedir?
# Cevabınız: float
# Corret!

# %%
print("1 veya 0 yada true false değerlerini barındıran veri tipine ne ad verilir?")
answer = str(input('Cevabınız: '))
if answer.lower() == 'bool':
  print("Corret! ")
  point = point + 10
else:
  print("WRONG!")
# Out:
# 1 veya 0 yada true false değerlerini barındıran veri tipine ne ad verilir?
# Cevabınız: bool
# Corret!

# %%
print("sıralı ve değiştirilemez olarak kullanılan () parantezler ile yazılan koleksiyon biçimine ne ad veriilir")
answer = str(input('Cevabınız: '))
if answer.lower() == 'tuple':
  print("Corret! ")
  point = point + 10
else:
  print("WRONG!")
# Out:
# sıralı ve değiştirilemez olarak kullanılan () parantezler ile yazılan koleksiyon biçimine ne ad veriilir
# Cevabınız: tuple
# Corret!

# %%
print("phytonda anahtar:değer biçiminde kullanılan {} parantezler ile oluşturulan koleksiyon biçimi nedir?")
answer = str(input('Cevabınız: '))
if answer.lower() == 'tuple':
  print("Corret! ")
  point = point + 10
else:
  print("WRONG!")

# %%
print("sıralı ve değiştirilemez olarak kullanılan () parantezler ile yazılan koleksiyon biçimine ne ad veriilir")
answer = str(input('Cevabınız: '))
if answer.lower() == 'dictionaries':
  print("Corret! ")
  point = point + 10
else:
  print("WRONG!")

# %%
print("liste elemanlarını sıralamak için kullandığımız metot nedir?")
answer = str(input('Cevabınız: '))
if answer.lower() == 'sort()':
  print("Corret! ")
  point = point + 10
else:
  print("WRONG!")

# %%
print("veriden anlamlı bilgi çıkarma ve verilerden değer elde etmek üzere bilimsel yöntemleri, süreçleri, algoritmaları ve sistemleri kullanan bir bilim dalına ne ad verilir?")
answer = str(input('Cevabınız: '))
if answer.lower() == 'veri bilimi':
  print("Corret! ")
  point = point + 10
else:
  print("WRONG!")

# %%
print("bilgisayarın veya bilgisayar kontrolündeki bir robotun çeşitli faaliyetleri zeki canlılara benzer şekilde yerine getirme kabiliyetine ne ad verilir")
answer = str(input('Cevabınız: '))
if answer.lower() == 'yapay zeka':
  print("Corret! ")
  point = point + 10
else:
  print("WRONG!")

# %%
if point <= 50:
  print("Başarısız oldunuz puanınız: %d tekrar deneyiniz!"%(point))
  else:
    print("TEBRİKLER Puanını: %d"%(point))
